# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0
x_train = x_train.reshape(-1,28,28,1)
x_train = x_train.reshape(-1,28,28,1)

# %%
model = tf.keras.models.Sequential ([
    tf.keras.layers.Conv2D(32, (3,3), activation ='tanh', input_shape =(28,28,1)),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='tanh'),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model.compile(optimizer = 'adam',
             loss= 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1906 - accuracy: 0.9446 - val_loss: 0.0943 - val_accuracy: 0.9729
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0737 - accuracy: 0.9787 - val_loss: 0.0738 - val_accuracy: 0.9776
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0491 - accuracy: 0.9854 - val_loss: 0.0644 - val_accuracy: 0.9791
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0345 - accuracy: 0.9896 - val_loss: 0.0562 - val_accuracy: 0.9819
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0236 - accuracy: 0.9930 - val_loss: 0.0647 - val_accuracy: 0.9797
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 0.0594 - val_accuracy: 0.9825
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.0592 - val_accuracy: 0.9821
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0721 - val_accuracy: 0.9798
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0660 - val_accuracy: 0.9817
# Epoch 10/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.0678 - val_accuracy: 0.9811

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label = 'Validation_Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.legend()
plt.subplot(1,2,2)
plt.plot(history.history['loss'],label = 'Training Loss')
plt.plot(history.history['val_loss'],label = 'Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.legend()

plt.show()
